# %% [markdown]
# ## A) IMPORTING LIBRARIES

# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
import re
from textblob import TextBlob
import gensim
import string

# nltk
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
stop_words = nltk.corpus.stopwords.words(['english'])

## All Sklearn Libraries
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix


## All Keras Libraries
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Embedding, Flatten, Conv1D, MaxPooling1D, LSTM
from keras import utils
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Other Useful Libraries
from collections import Counter
import logging
import time
import pickle
import itertools
import warnings
from wordcloud import WordCloud
lem = WordNetLemmatizer()
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nikhiljoshi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## B) READING RAW DATA

# %%
tweets=pd.read_csv('/Users/nikhiljoshi/Capstone Project/EDA Files/after_eda.csv')
#tweets=pd.read_csv('C:\\Users\\W0780808\\Downloads\\after_eda.csv')
tweets_orig=tweets
tweets_orig
# Out:
#                    Datetime             Tweet Id  \
# 0       2022-05-28 14:07:28  1530551333899616256
# 1       2022-05-28 10:07:40  1530490986001969152
# 2       2022-05-28 04:16:27  1530402599618244610
# 3       2022-05-27 15:47:59  1530214238320467969
# 4       2022-05-27 15:31:08  1530210001649811458
# ...                     ...                  ...
# 505101  2017-12-31 09:30:00   947399429383786496
# 505102  2017-12-31 09:00:01   947391885525516288
# 505103  2017-12-31 08:22:32   947382453009879040
# 505104  2017-12-31 06:30:00   947354130661519361
# 505105  2017-12-31 05:30:00   947339031620259840
#
#                                                      Text        Location  \
# 0       @elonmusk i think twitter bird is now free. Bu...             NaN
# 1       @joydeepg9 @Deekay01119442 @TNSubbaRao1 There ...       बस यहीं..
# 2       @nytimes Once again the entitled NYT wants to ...             NaN
# 3       #NoWonder #China's #WhiteTerror or #BlueTerror...             NaN
# 4       Hey, what a surprise, 1 year later and nada! #...        New York
# ...                                                   ...             ...
# 505101  Father returns from overseas wedding after son...   San Francisco
# 505102  Future unclear for White House Commission on #...   San Francisco
# 505103  Happy New year to my fav #Aapi on #Twitter @Ar...  Lleida, España
# 505104  NY Times called out for misstep in Asian cultu...   San Francisco
# 505105  How an #Asian American woman fought for her ci...   San Francisco
#
#         Retweet  Like                                       new_Hashtags
# 0             1     1                                       chinesevirus
# 1             0     2                          chinesevirus bollywoodias
# 2             0     0                                       chinesevirus
# 3             2     6  nowonder china whiteterror blueterror ccp free...
# 4             1     0         justafriendlyreminder chinesevirus coverup
# ...         ...   ...                                                ...
# 505101        0     1                                               aapi
# 505102        0     1                                         asian aapi
# 505103        1     0                                       aapi twitter
# 505104        0     1                                               aapi
# 505105        0     1                                         asian aapi
#
# [505106 rows x 7 columns]

# %% [markdown]
# ## C) PRE - PROCESSING DATA

# %% [markdown]
# ##### - *In the code below, we have used various pre processing techniques to remove stop words, perform lemmatization, remove emojis etc., in order to prepare our data for further analysis.*

# %%
def decontracted(phrase):

    # specific
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    #phrase = re.sub(r"n't", " not", phrase) # resulted in "ca not" when sentence started with "can't"
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"won\’t", "will not", phrase)
    phrase = re.sub(r"can\’t", "can not", phrase)
    #phrase = re.sub(r"n't", " not", phrase) # resulted in "ca not" when sentence started with "can't"
    phrase = re.sub(r"\’re", " are", phrase)
    phrase = re.sub(r"\’s", " is", phrase)
    phrase = re.sub(r"\’d", " would", phrase)
    phrase = re.sub(r"\’ll", " will", phrase)
    phrase = re.sub(r"n\’t", " not", phrase)
    phrase = re.sub(r"\’ve", " have", phrase)
    phrase = re.sub(r"\’m", " am", phrase)
    return phrase

# %%
import emoji
# Remove cant wont words
tweets['Text']=tweets['Text'].apply(lambda x : decontracted(x))

#Converting to Lowercase
tweets['Text']=tweets['Text'].apply(lambda x : x.lower())

# removing emojis
def strip_emoji(text):
    return re.sub(emoji.get_emoji_regexp(), r"", tweets['Text'])

# %%
def cleaning(data):
    #removing url's
    tweet_without_url = re.sub(r'http\S+',' ', data)

    #remove all hashtags
    tweet_without_hashtag = re.sub(r'#\w+', ' ', tweet_without_url)

    #Removing all "@" mentions and characters which are not alphabets
    tweet_without_mentions = re.sub(r'@\w+',' ', tweet_without_hashtag)
    precleaned_tweet = re.sub('[^A-Za-z]+', ' ', tweet_without_mentions)

    # Tokenizing Data
    tweet_tokens = TweetTokenizer().tokenize(precleaned_tweet)

    #Removal of Punctuations
    tokens_without_punc = [w for w in tweet_tokens if w.isalpha()]
    
    #Removal of Stopwords
    tokens_without_sw = [t for t in tokens_without_punc if t not in stop_words]

    #Performing Lemmatization
    text_cleaned = [lem.lemmatize(t) for t in tokens_without_sw]

    #Joining everything in the end
    return " ".join(text_cleaned)

# %% [markdown]
# ##### - *After all the preprocessing steps, we will see how our "Text" data looks like.*

# %%
tweets['Text']=tweets['Text'].apply(cleaning)
tweets.head()
# Out:
#               Datetime             Tweet Id  \
# 0  2022-05-28 14:07:28  1530551333899616256
# 1  2022-05-28 10:07:40  1530490986001969152
# 2  2022-05-28 04:16:27  1530402599618244610
# 3  2022-05-27 15:47:59  1530214238320467969
# 4  2022-05-27 15:31:08  1530210001649811458
#
#                                                 Text   Location  Retweet  \
# 0                 think twitter bird free cage china        NaN        1
# 1  sea change indian temperament lately yr galwan...  बस यहीं..        0
# 2  entitled nyt want lecture darker colored every...        NaN        0
# 3             terrorizing chinese people regime work        NaN        2
# 4                       hey surprise year later nada   New York        1
#
#    Like                                       new_Hashtags
# 0     1                                       chinesevirus
# 1     2                          chinesevirus bollywoodias
# 2     0                                       chinesevirus
# 3     6  nowonder china whiteterror blueterror ccp free...
# 4     0         justafriendlyreminder chinesevirus coverup

# %% [markdown]
# ### D) INTRODUCING TEXTBLOB

# %% [markdown]
# ##### - *We will be using TextBlob library to calculate the Polarity and subjectivity of a tweet to see the division of positive,negative or neutral tweets.*

# %%
def getSubjectivity(tweet):
    return TextBlob(tweet).sentiment.subjectivity

def getPolarity(tweet):
    return TextBlob(tweet).sentiment.polarity

# %% [markdown]
# ##### - *2 new columns have been added for both the metrices mentioned above.*

# %%
# New Column 1
tweets['Subjectivity'] = tweets['Text'].apply(getSubjectivity)
# New Column 2
tweets['Polarity'] = tweets['Text'].apply(getPolarity)
tweets.head()
# Out:
#               Datetime             Tweet Id  \
# 0  2022-05-28 14:07:28  1530551333899616256
# 1  2022-05-28 10:07:40  1530490986001969152
# 2  2022-05-28 04:16:27  1530402599618244610
# 3  2022-05-27 15:47:59  1530214238320467969
# 4  2022-05-27 15:31:08  1530210001649811458
#
#                                                 Text   Location  Retweet  \
# 0                 think twitter bird free cage china        NaN        1
# 1  sea change indian temperament lately yr galwan...  बस यहीं..        0
# 2  entitled nyt want lecture darker colored every...        NaN        0
# 3             terrorizing chinese people regime work        NaN        2
# 4                       hey surprise year later nada   New York        1
#
#    Like                                       new_Hashtags  Subjectivity  \
# 0     1                                       chinesevirus        0.8000
# 1     2                          chinesevirus bollywoodias        0.4375
# 2     0                                       chinesevirus        0.0000
# 3     6  nowonder china whiteterror blueterror ccp free...        0.0000
# 4     0         justafriendlyreminder chinesevirus coverup        0.0000
#
#    Polarity
# 0       0.4
# 1       0.1
# 2       0.0
# 3       0.0
# 4       0.0

# %% [markdown]
# ##### - *To textualize and analyze these newly added metrices, we add labels along with a new column named "Sentiment".*

# %%
def getSentiment(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

tweets['Sentiment'] = tweets['Polarity'].apply(getSentiment)
tweets.head()
# Out:
#               Datetime             Tweet Id  \
# 0  2022-05-28 14:07:28  1530551333899616256
# 1  2022-05-28 10:07:40  1530490986001969152
# 2  2022-05-28 04:16:27  1530402599618244610
# 3  2022-05-27 15:47:59  1530214238320467969
# 4  2022-05-27 15:31:08  1530210001649811458
#
#                                                 Text   Location  Retweet  \
# 0                 think twitter bird free cage china        NaN        1
# 1  sea change indian temperament lately yr galwan...  बस यहीं..        0
# 2  entitled nyt want lecture darker colored every...        NaN        0
# 3             terrorizing chinese people regime work        NaN        2
# 4                       hey surprise year later nada   New York        1
#
#    Like                                       new_Hashtags  Subjectivity  \
# 0     1                                       chinesevirus        0.8000
# 1     2                          chinesevirus bollywoodias        0.4375
# 2     0                                       chinesevirus        0.0000
# 3     6  nowonder china whiteterror blueterror ccp free...        0.0000
# 4     0         justafriendlyreminder chinesevirus coverup        0.0000
#
#    Polarity Sentiment
# 0       0.4  Positive
# 1       0.1  Positive
# 2       0.0   Neutral
# 3       0.0   Neutral
# 4       0.0   Neutral

# %%
import gradio as gr
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
def func(Tweet):
  return 'SubjectivityScore:' + str(getSubjectivity(Tweet)), classifier(Tweet), 'PolarityScore:' + str(getPolarity(Tweet))

descriptions = "Subjectivity, Classifier, Polarity of Tweets!"

app = gr.Interface(fn=func  , inputs="text", outputs="text", title="Sentiment Analysis Application", description=descriptions)
app.launch(share=True)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Running on local URL:  http://127.0.0.1:7865/
# Running on public URL: https://33343.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://33343.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x2b7f98c10>,
#  'http://127.0.0.1:7865/',
#  'https://33343.gradio.app')

# %% [markdown]
# ## E) EXPLORING DATA POST TEXTBLOB

# %% [markdown]
# ##### - *In the code below, we will plot the Sentiment labels to observe the distribution of tweets.*

# %%
sns.histplot(tweets['Sentiment'])
# Out:
# <AxesSubplot:xlabel='Sentiment', ylabel='Count'>

# %% [markdown]
# ##### - *Analyzing the wordcloud for Positive and Negative Tweets seperately*

# %%
# # Positive Tweets
# all_words = ' '.join([text for text in tweets['Text']]) 

# from wordcloud import WordCloud
# wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words) 
# plt.figure(figsize=(10, 7)) 
# plt.imshow(wordcloud, interpolation="bilinear") 
# plt.axis('off')
# plt.show()
# ## We cant really see the words associated with potive or negatove tweets hence we'll plot them seperately

# %%
# Negative Tweets
normal_words =' '.join([text for text in tweets['Text'][tweets['Sentiment'] == "Negative"]]) 
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## F) DEFINING TRAINING AND TEST DATASET

# %% [markdown]
# ##### - *We already have labelled dataset that we'll be using to train our models. The below code gives us a snippet of the data.*

# %%
df=pd.read_csv('/Users/nikhiljoshi/Capstone Project/ML Models/minimum_cleaned_balanced training data.csv')
sns.histplot(df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='Count'>

# %% [markdown]
# # G) TEXT EMBEDDING APPROACHES

# %% [markdown]
# ####    1) BOW
#             - ML Models used:
#                 1.1) Naive Bayes Model
#                 1.2) KNN Model
#                 1.3) Decision Tree Model
#                 1.4) Random Forest Model
#                 1.5) SVC Model
# ####    2) TF-IDF
#             - ML Models Used
#                 2.1) Naive Bayes Model
#                 2.2) KNN Model
#                 2.3) Decision Tree Model
#                 2.4) Random Forest Model
#                 2.5) SVC Model

# %% [markdown]
# # H) ML MODELS WITH BOW

# %% [markdown]
# #### Creating Corpus 1 and using BOW Technique

# %%
corpus = [] # Build a new list for all the words from all the reviews

# corpus is a collection of text and a common term used in NLP
for i in range (0, len(df['Text'])):
    review = re.sub('[^a-zA-Z]', ' ', df['Text'][i] )
    review = review.lower()
    review = review.split()
    ps =PorterStemmer()
    review = [ps.stem(word) for word in review if not  word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['still allow quot ancient chines proverb racist racismisaviru',
#  'power chines viru thing realli shown us crazi low iq peopl went sam club costco morn store line wrap around build get insid fuck left disappoint human',
#  'cnbc tedro reiter viru could still turn pandem urg fear panic ad greatest enemi right viru fear rumor stigma via',
#  'heighten racism experienc asian commun surpris mani peopl belief racial progress widespread american societi covid racismisaviru strongertogeth asianamerican',
#  'coronaviru nepali china kp oli direct offici bring back nepali wuhan china keep',
#  'iamnotaviru heard use imag articl covid patient outsid china',
#  'proven past year hate american america place countri risk busi fake impeach worri chines viru pelosi want tri money',
#  'fact coronaviru probabl come us becom world pandem fact legaci media democrat tri blame fact ought preempt china commi nation narrow window make abundantli clear',
#  'last fuck time coronaviru excus racist asian',
#  'think campaign slogan mama make america manufactur need make stuff america happen chines viru open eye depend anoth countri',
#  'fuck china covid via exactli thought must held account chineseviru',
#  'anyon els sneaki fist pump everi recycl bin street goe thud put pressur wagon hydraul goe chink chink bottl',
#  'well shit coronaviru',
#  'hope april st come around news broadcast like april fool coronaviru isnt real joke shit ton old china men come behind curtain',
#  'disgust media moral bankrupt chinacommunistparti chinaliedpeopledi',
#  'tweet support iamnotaviru hashtag respect asian american american',
#  'anoth wuhan hospit chief hospitalis contract coronaviru treat patient coronavirusoutbreak',
#  'barback weekend hear stupid shit time point wish actual coronaviru bottl',
#  'worri coronaviru coronaviru',
#  'lose mind quarantin make mad chines douchebag ate shit infect everyon chineseviru whole world suffer bloodi shitbag bloodi ban china ban chines peopl coronaviru',
#  'gray plagu fuck go qom coronaviru wuflu',
#  'ccp china type shadi evil shit one bat eye trump call viru start china chineseviru chinaliedpeopledi ccpliedpeopledi',
#  'much chines viru yo ass sponsor fuck countri quarantin',
#  'husband sorri got rest us coronaviru tend littl groan peopl blow nose scratchi tp week get sick flaccid sorri wife',
#  'coronaviru elect put democrat difficult spot',
#  'ever seen anyon pray death american',
#  'fuck chineseviru',
#  'fuck china wuhanviru covid coronaviru covid wuhancoronavirusoutbreak wuhanpneumonia standup humanright hongkong korea us germani hongkong japan uk itali iran',
#  'watch cri wtf america serious w f coronaviruspandem covid asianamerican racismisaviru',
#  'truth chinaliedpeopledi',
#  'told doctor buddi januari ask wuhan viru prepar worst close ad agenc monday februari sent everyon home china cover whole damn thing fascist beij pure damn evil',
#  'fuck china chinaviru',
#  'keep eat bat rat dog cat tell us civil countri come china own pandem entir work know stfu kungflu fu',
#  'passeng coronaviru stricken cruis ship disembark florida head hospit airport',
#  'dearpr trump great joband take year peopl understand much love americaand world patriot certainli right way fight terrorist peopl iran appreci kill soleimani coronaviru',
#  'ye china knew outbreak start quaraneten whole ass citi rapidli built',
#  'hear woman refus get test one spread fuck',
#  'chines horribl fuck chinaliedpeopledi boycottchina wuhanviru',
#  'ccp racismisaviru ccpviru',
#  'hell know pandem public health incompet reign trumplandia croni lackey sycoph',
#  'poor ghost kenya nigga took chines govern got blood viru million condemn god repay sky thunder hack black dog',
#  'check news coronaviru covid covid covid wuhan coronaviruschina wuhancoronaviru chinaviru gt share rt',
#  'yo american came back japan coronaviru coronaviru evolv untrac actual dead china fuck kill everyon gg',
#  'fuck ya commi',
#  'w h coronaviru countri britain tea america omfg aaaaaaaaahhhhhhh go die want die arab chines oh god save us presid trump babi jesu go die',
#  'covid start cuz chink want bat soup',
#  'discrimin okay matter caus tension high covid mani asian american take social media campaign like washtheh racismisaviru iamnotcovid empow commun fight back',
#  'china warn fire laser us aircraft rival enemi aapl amzn agn brk ba bhc crm cmg f ge gm ko ibm pep tst iep wfc ms gs jpm bac c sbux cpe googl cat nwl wynn qsr shak mcd msft nflx',
#  'coronaviru xenophob racist get matter give reason thing pandem affect everyon stop target asian',
#  'coronaviru live updat pakistan coronaviru live updat pakistan covid diseas caus sar cov viru start spread decemb wuhan china covid name world health organ acronym base coronaviru disea',
#  'american go work wear mask contact someon covid outrag',
#  'coronaviru updat must watch video biggest warn lifetim much time left coronaviru covid coronaviriu covid coronavirususa coronaviruscoverup viru viral chinavirussesungguhnya chine whotwi',
#  'wuhan flu wuflu kungflu chines viru whatev bet ass origin nyc philli chicago citi would part name',
#  'governa chineseee problem fuck coranavirusitalia china chinaviru coronaviru itali problem',
#  'amaz potu beat wuhanviru punish china unleash',
#  'kinda fuck egg coronaviru',
#  'got faruqin kid mehreen seriou expect au taxpay fund intern student realli retard auspol chineseviru coronaviru',
#  'hp zbook v g intel core th gen cpu gb ram tb storag gb nvidia quadro p gddr ke',
#  'chines govern say bioweapon claim u releas treati',
#  'say china eat anim kill anim eat anim anim product make sick die corona viru god see everyth coronaviru peopl cruel anim forbid eat anim forbid cruelti anim forbid kill anim urgent',
#  'coronaviru plant china us oper',
#  'let chineseviru establish critic mass high densiti area benefit season chang slow spread diminish aggress earli slow spread buy time area need nyc fuck big time',
#  'ayeee get readi laynewcharitysong',
#  'countri ruin world heard corona viru hope wipe u shit cunt',
#  'chines viru defect mask fuck china',
#  'world special india never forgiv chines peopl chines govern play dirti ga',
#  'mani thai support anti china taiwan hongkong independ call viru chines viru fuck funni europ america call asian viru',
#  'rushlimbaugh fli fat ass wuhan hangout hour coronaviru common cold bet chicken ass spread disinform like russian thing fool gopbetrayedamerica gopcoverup coronaviriu',
#  'hey china thank liter fuck planet constant pandem covid thankschina',
#  'pl retweet write asian american vastli repres among front line medic worker doctor pa nurs us asian yet face rise violenc hate asian becool asian frontlinework covid',
#  'racism china covid help give iamnotaviru',
#  'gone much far disgust fk racist asian',
#  'coronaviru start bill gate compani lab china purpos leak kill get countri nation world worship beast plan kill billion depopul includ usa',
#  'two get anymor ignor fredo littl whini bitch wuhanviru',
#  'question one infect person dog liter shit excrement end lake mani ppm coronaviru take get someon infect bioweapon mayb viru super spreader could doom ppl theoret',
#  'keep hear read asian verbal even physic attack say racismisaviru',
#  'confus viru transmit human human human street ppl quarantin spray street anoth video chemic disinfect street wuhan coronaviru fbr',
#  'n ppl tri come say stop call da chines viru creat da shit even govern stop fund danger ass trial look stupid n defend da chines u want want di happen',
#  'appar coronaviru enter human bodi connect someth call ace receptor east asian men say white european women white woman seem way much lesser risk',
#  'racist call chines viru blatant lie say china blame neo liber echo phrase invari refus consid repatri pharmaceut manufactur inustri divert blame',
#  'xi jinp wherev goe whole world turn nose xi jinp evil fetid rat stay home eat wok fri bat xi jinp intern pariah spread filth scummi chines liar chineseviru',
#  'fake news communist media accomplish everi chines viru brief show america much truli hate america time need come togeth yet want divid us',
#  'china entir cultur lack good hygien common courtesi tbh occ',
#  'like fuck take realli wtf paper ad say fear coronaviru call us extermin hous written chines realli wtf want give trash besid throw',
#  'well done sir',
#  'dear democrat liber leftist progress peopl attack chines trump call vir',
#  'may fate bestow coronaviru upon po',
#  'covid coronaviru wuflu nih scientist identifi atom structur novel coronaviru protein',
#  'jenesuispasunviru iamnotaviru believ scienc rumor go china',
#  'texa base compani claim complet coronaviru vaccin covid cdc worldhealthorgan',
#  'see chines face coronaviru racism xenophobia agst chines asian around world wave sinophobia tell us way fear china bbc news analysi covid jenesuispasunviru iamnotaviru',
#  'wear mask alreadi coronaviru ya chinki fuck',
#  'fact told us chines viru transfer human human fact transfer human human liberalismisamentaldisord',
#  'absolut joke man cut salari wuhanviru enemi get head ass',
#  'coronaviru whole world must take action warn',
#  'shit new coronaviru may spread poop',
#  'yaack fuck chines viru origin',
#  'ca believ got rob potenti sextupl chink ate bat',
#  'make mad peopl realli think social distanc quarantin appli friend problem',
#  'angel c netizen mad donat sk instead give fuck esp bash poor girl want help shameless fyi talk chines patient noth jealou bitch tri make polit',
#  'number coronaviru case korea jump',
#  'boogaloo bioweapon govern scientist discov hiv like mutat make coronaviru extrem infecti zero hedg',
#  'vaccin cure bat shit chinaliedpeopledi chinaviru',
#  'good spot though find well least pass time',
#  'ccp go stick ass prison coronaviru coronaoutbreak coronavirusoutbreak',
#  'somebodi said corona viru stop eat chines food hiv stop fuck raw',
#  'seem like chink flu got boy bori stay strong king',
#  'part speak racist languag idea associ asian peopl covid stigma washtheh utahwashtheh',
#  'call chines viru anymor viciou stab asian american famili includ year old girl sam club texa earlier month deem hate crime fed',
#  'imagin uniron think point call chines viru incit racism cape asian like basic human decenc',
#  'pdx also farmer market go basic argument farmer ai wrong unconscion h',
#  'fairli fuck typic ever america centric leftist take covid panic racist actual asian countri viral equival defcon shut school major event lock intern travel',
#  'chernobyl disast reveal far soviet union go implement glasnost covid reveal likewis china far go becom candid open regard tragic consequ anim market eat bat',
#  'go war without ammunit doctor reveal like treat coronaviru patient hospit scrambl suppli getmepp getuspp',
#  'would especi urg fellow jewish friend us patronis local chines restaur takeout extra atm american jew histor special bond american chines food place need help counteract racist ignor paranoia coronaviru',
#  'call racist know care woman critic suppos viru born chines lab china releas world without evid fight viru grow togeth one human mankind point other',
#  'hospit built wuhan china day accommod coronaviru patient kenya leav peopl scott free interact peopl china daili basi without care diseas strike dawn truli karma bitch',
#  'fuck fat chink prick',
#  'fuck stupid viru china communist regim link market sell upcom recess viru trump pathet',
#  'parent pakistani student stuck china coronaviru outbreak protest govt advisor zulfi bokhari zafar mirza run away presser',
#  'everybodi talk ai eat chines corona viru done ate shit like time last week buss',
#  'look pax east next week even mad dummo comment tho',
#  'fight defend asian origin individu experienc discrimin washtheh covid',
#  'obvious major go white white major austin cours someth chink brain comprehend',
#  'jesu christ that fuck least someth danger like ebolapox real bioweapon get still horrid made care around',
#  'asian american experienc racist attack due claim covid chines viru racist ok need stop share rais awar stereotyp violenc asian american commun current face iamnotaviru',
#  'attn call stori experi workplac strife xenophobia harass caregiv relat coronaviru slide dm esp health care worker ride share taxi transit worker sex worker massag worker xenophobia covid iamnotaviru',
#  'chines viru asian peopl get violent attack scream see friend f',
#  'happen woman walk around chinatown yell coronaviru curs asian unit peac corp neighborhood watch group notifi faith leader way diffus situat get help kudo hateisaviru covid',
#  'asian american use social media mobil attack covid caronaviru washtheh racismisaviru',
#  'let trend chineseviru till loser stop eat shit eat chineseviru chineseviru chineseviru chineseviru chineseviru chineseviru',
#  'hear ya instead coup like damn chicken thank china chineseviru',
#  'chines viru yet follow still find way tri defend racist',
#  'wonder chines author count casualti die viru test result come chinaliedpeopledi',
# ...
#  'fuck china chinaviru chinaviru chinaliedpeopledi',
#  'prolli someth coronaviru china look get either peopl fuck sensit anymor',
#  'ridicul sure un everi bloodi countri world need ask fuck think china',
#  'funniest shit american complain china handl coronaviru viru start america us would wipe bc boomer demand let quarantin bc miss tequila bingo night',
#  'ok democrat enough enough everyon polit correct enough lie afraid speak want spick chink presid trump hell good job leav alon stupid enough fall coronaviru',
#  'fuck chines girl found coronaviru',
#  'saudiarabia plead muslim delay hajj face covid erdogan want ordinari turk donat money coronaviru treatment skeptic follow anoth chanc put huge popular front page',
#  'everi member execut feder state local govern fail heed warn covid covid pandem must refus medic treatment sign dnr',
#  'real piec shit tri sneak billion abort crap emerg spend bill help protect american wuflu way go',
#  'fuck chines viru fucker countri start shit',
#  'solidar china market jewish chines commun iamnotaviru shoppingagainstprejudic purim',
#  'absolut disgrac dare speak anyon like let alon custom hope peopl involv',
#  'u ur shit pungent radic islam muslim jighadi fiyadeen invad killer chines viru spreader anim eater jamaat r highli injuri danger nation entir human henc die virgin wait heaven ensoy travel road',
#  'racist think countri capac deal coronaviru racist feel peopl need protect allow chines china risk',
#  'one disgust thing seen',
#  'chineseviru fuck china viru fuck chines food suck',
#  'glenn pull stop one biggovviru',
#  'tri capit fear coronaviru',
#  'butthurt chink lmfaooo',
#  'coronaviru wake call world china communist practic ignor god abraham includ satan treatment anim eat cook live bat cat dog etc result plagu persecut jew christian etc almighti furiou',
#  'increas attack verbal abus vandals target asian sibl harrow must stop racismisaviru',
#  'covid fear exploit attack exclud minor say scapego minor lead alarm rise verbal physic abus chines minor learn iamnotaviru fightrac',
#  'watch race coronaviru bay area convers abc confront hate crime asian american covid pandem interact town hall see alli washtheh',
#  'nation poll say asian four time like discrimin iamnotaviru',
#  'dismiss taken bribe china taken money china taken action china understand coronavirus big busi china covid chineseviru danger also hydrogen bomb',
#  'sure want speak start subtl racism peopl asian commun viru start unfortun past week hate becom harder ignor covid washtheh',
#  'hi guy want fuck kneel wichita fall maturemilf coronaviru',
#  'would especi urg fellow jewish friend us patronis local chines restaur takeout extra atm american jew histor special bond american chines food place need help counteract racist ignor paranoia coronaviru',
#  'whole damn presid racist parti call covid chinaviru republican stole georgia gov role black woman staci abram etc',
#  'obito coronaviru wassup bitch minato oh shi obito gonna come get',
#  'dri seafood larg size scallop pound gram south china sea',
#  'believ shit china itali take seriou till got hand let happen coronaviru',
#  'chines fuck breed',
#  'think anyon stupid enough boycott corona music coronaviru',
#  'evil white man fault call chines viru would racist',
#  'bro fuck common cold work scari',
#  'real situat china fuck twitter keep remov video retweet share follow regular video updat direct china coronaviru coronoavirusoutbreak coronaviruswuhan coronaviruswuhan',
#  'racist call viru chines viru racist call spanish',
#  'hahaha worri fuck chines let chines viru pandem end readi destroy china',
#  'pleas help trend w',
#  'said noth worri argu border closur said viru could pass human human surpris govern listen suppos think happen corrupt useless ccpviru',
#  'covid coronaviru wuflu total case diamond princess yokohama',
#  'dr fauci hydroxychloroquin treat coronaviru care make amajest leap foxnew fuck wrong liber quack po zap hope suffer chineseviru need go asap',
#  'fuck hypochondriac crave chines even tho diet ima still get tonight',
#  'peopl iran itali say shit super seriou deadli fli face everyth led believ china even unit state coronaviru',
#  'mad caus trump call chines viru mean origin market eat bat',
#  'yeah corona viru oeool avoid chines food fuck get orang chicken china express',
#  ...]

# %%
cvec = CountVectorizer()
X = cvec.fit_transform(corpus).todense()
y = df.iloc[:,1].values

# %% [markdown]
# ### Splitting Data in Test and Training Dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X , y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ### 1.1) Naive Bayes Model

# %%
classifierused = GaussianNB() # Defining the classifier used
classifierused.fit(X_train, y_train) # Fitting Classifier to the Training Data Set

# Predicting the results below
y_pred = classifierused.predict(X_test)

# Generating Confusion Matrix
cmatrix = confusion_matrix(y_test, y_pred)

# Generating Accuracy Scores
accuracy = accuracy_score(y_test, y_pred)

#Preparing Confusion Matrix Heatmap
df_for_cm = pd.DataFrame(cmatrix, range(3),range(3))
sns.set(font_scale=1.6)
sns.heatmap(df_for_cm, annot_kws={"size": 15},fmt='g',annot=True)

# Printing Classification Report for Precision, recall and F1 Score
print(classification_report(y_test, y_pred))

#Printing Accuracy Scores
print("Accuracy on test Dataset is:",round(accuracy,2))
print("Accuracy on training Dataset is:", round(classifierused.score(X_train,y_train),2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.49      0.57       268
#            1       0.65      0.75      0.70       221
#            2       0.61      0.72      0.66       278
#
#     accuracy                           0.65       767
#    macro avg       0.65      0.65      0.64       767
# weighted avg       0.65      0.65      0.64       767
#
# Accuracy on test Dataset is: 0.65
# Accuracy on training Dataset is: 0.93

# %% [markdown]
# ### 1.2) KNN Model

# %%
knn = KNeighborsClassifier(n_neighbors=20)  # Defining the classifier used
knn.fit(X_train, y_train) # Fitting Classifier to the Training Data Set

# Predicting the results below 
y_pred=knn.predict(X_test)

# Generating Confusion Matrix
cmatrix = confusion_matrix(y_test, y_pred)

# Generating Accuracy Scores
accuracy = accuracy_score(y_test, y_pred)

df_for_cm = pd.DataFrame(cmatrix, range(3),range(3))
sns.set(font_scale=1.6)
sns.heatmap(df_for_cm, annot_kws={"size": 15},fmt='g',annot=True)

#Printing results
print("Accuracy on test Dataset is:",round(accuracy,2))
print("Accuracy on training Dataset is:", round(knn.score(X_train,y_train),2))


# Printing Classification Report for Precision, recall and F1 Score
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on test Dataset is: 0.52
# Accuracy on training Dataset is: 0.57
#               precision    recall  f1-score   support
#
#            0       0.45      0.81      0.58       268
#            1       0.89      0.18      0.29       221
#            2       0.59      0.53      0.56       278
#
#     accuracy                           0.52       767
#    macro avg       0.64      0.50      0.48       767
# weighted avg       0.63      0.52      0.49       767

# %% [markdown]
# ### 1.3) Decision Tree Model

# %%
dt_clf = DecisionTreeClassifier(criterion = 'entropy', random_state= 0) # Defining the classifier used
dt_clf.fit(X_train, y_train)  # Fitting Classifier to the Training Data Set

# Predicting the results below
y_pred = dt_clf.predict(X_test)


# Generating Confusion Matrix
cmatrix = confusion_matrix(y_test, y_pred)

# Generating Accuracy Scores
accuracy = accuracy_score(y_test, y_pred)

#Preparing Confusion Matrix Heatmap
df_for_cm = pd.DataFrame(cmatrix, range(3),range(3))
sns.set(font_scale=1.6)
sns.heatmap(df_for_cm, annot_kws={"size": 15},fmt='g',annot=True)

#Printing results
print("Accuracy on test Dataset is:",round(accuracy,2))
print("Accuracy on training Dataset is:", round(dt_clf.score(X_train,y_train),2))


# Printing Classification Report for Precision, recall and F1 Score
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on test Dataset is: 0.7
# Accuracy on training Dataset is: 1.0
#               precision    recall  f1-score   support
#
#            0       0.63      0.74      0.68       268
#            1       0.82      0.77      0.80       221
#            2       0.69      0.60      0.64       278
#
#     accuracy                           0.70       767
#    macro avg       0.71      0.71      0.71       767
# weighted avg       0.71      0.70      0.70       767

# %% [markdown]
# ### 1.4) Random Forest Model

# %%
# Fitting classifier to the Training set

# Defining the classifier used
model = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state=0) 

model.fit(X_train, y_train)     # Fitting Classifier to the Training Data Set

# Predicting the results below
y_pred = model.predict(X_test)

# Generating Confusion Matrix
cmatrix = confusion_matrix(y_test, y_pred)

# Generating Accuracy Scores
accuracy = accuracy_score(y_test, y_pred)

#Preparing Confusion Matrix Heatmap
df_for_cm = pd.DataFrame(cmatrix, range(3),range(3))
sns.set(font_scale=1.6)
sns.heatmap(df_for_cm, annot_kws={"size": 15},fmt='g',annot=True)


#Printing results
print("Accuracy on test Dataset is:",round(accuracy,2))
print("Accuracy on training Dataset is:", round(model.score(X_train,y_train),2))


# Printing Classification Report for Precision, recall and F1 Score
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on test Dataset is: 0.75
# Accuracy on training Dataset is: 0.99
#               precision    recall  f1-score   support
#
#            0       0.67      0.77      0.72       268
#            1       0.86      0.76      0.81       221
#            2       0.74      0.71      0.73       278
#
#     accuracy                           0.75       767
#    macro avg       0.76      0.75      0.75       767
# weighted avg       0.75      0.75      0.75       767

# %% [markdown]
# ### 1.5) SVC Model

# %%
clf = SVC(kernel = 'linear')    # Defining the classifier used

clf.fit(X_train, y_train)      # Fitting Classifier to the Training Data Set

# Predicting the results below
y_pred = clf.predict(X_test)

# Generating Confusion Matrix
cmatrix = confusion_matrix(y_test, y_pred)

# Generating Accuracy Scores
accuracy = accuracy_score(y_test, y_pred)

#Preparing Confusion Matrix Heatmap
df_for_cm = pd.DataFrame(cmatrix, range(3),range(3))
sns.set(font_scale=1.6)
sns.heatmap(df_for_cm, annot_kws={"size": 15},fmt='g',annot=True)

#Printing results
print("Accuracy on test Dataset is:",round(accuracy,2))
print("Accuracy on training Dataset is:", round(clf.score(X_train,y_train),2))

# Printing Classification Report for Precision, recall and F1 Score
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on test Dataset is: 0.74
# Accuracy on training Dataset is: 0.99
#               precision    recall  f1-score   support
#
#            0       0.67      0.76      0.71       268
#            1       0.86      0.78      0.82       221
#            2       0.73      0.69      0.71       278
#
#     accuracy                           0.74       767
#    macro avg       0.75      0.74      0.74       767
# weighted avg       0.74      0.74      0.74       767

# %% [markdown]
# # I) ML MODELS WITH TF-IDF

# %% [markdown]
# #### Creating Corpus 2 and using TF-IDF Technique

# %%
corpus2 = []

for i in range (0, len(df['Text'])):
    review = re.sub('[^a-zA-Z]', ' ', df['Text'][i] )
    review = review.lower()
    review = review.split()
    ps =PorterStemmer()
    review = [ps.stem(word) for word in review if not  word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus2.append(review)

# %%
vectorizer = TfidfVectorizer (max_features=2500, min_df=7, max_df=0.8, stop_words=stopwords.words('english'))
corpus2 = vectorizer.fit_transform(corpus2).toarray()
X=corpus2

# %%
y = df.iloc[:,1].values

# %% [markdown]
# ### 2.1) Naive Bayes Model

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,y, test_size=0.2,random_state = 0)
classifierused = GaussianNB()   # Defining the classifier used
classifierused.fit(X_train, y_train)     # Fitting Classifier to the Training Data Set

# Predicting the results below
y_pred = classifierused.predict(X_test)

# Generating Confusion Matrix
cmatrix = confusion_matrix(y_test, y_pred)

# Generating Accuracy Scores
accuracy = accuracy_score(y_test, y_pred)

#Preparing Confusion Matrix Heatmap
df_for_cm = pd.DataFrame(cmatrix, range(3),range(3))
sns.set(font_scale=1.6)
sns.heatmap(df_for_cm, annot_kws={"size": 15},fmt='g',annot=True)

#Printing results
print("Accuracy on test Dataset is:",round(accuracy,2))
print("Accuracy on training Dataset is:", round(classifierused.score(X_train,y_train),2))


# Printing Classification Report for Precision, recall and F1 Score
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on test Dataset is: 0.6
# Accuracy on training Dataset is: 0.78
#               precision    recall  f1-score   support
#
#            0       0.62      0.58      0.60       268
#            1       0.57      0.77      0.66       221
#            2       0.64      0.49      0.56       278
#
#     accuracy                           0.60       767
#    macro avg       0.61      0.61      0.60       767
# weighted avg       0.61      0.60      0.60       767

# %% [markdown]
# ### 2.2) KNN Model

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,y, test_size=0.2,random_state = 0)


knn = KNeighborsClassifier(n_neighbors=30)  # Defining the classifier used
knn.fit(X_train, y_train) # Fitting Classifier to the Training Data Set

# Predicting the results below 
y_pred=knn.predict(X_test)

# Generating Confusion Matrix
cmatrix = confusion_matrix(y_test, y_pred)

# Generating Accuracy Scores
accuracy = accuracy_score(y_test, y_pred)

df_for_cm = pd.DataFrame(cmatrix, range(3),range(3))
sns.set(font_scale=1.6)
sns.heatmap(df_for_cm, annot_kws={"size": 15},fmt='g',annot=True)

#Printing results
print("Accuracy on test Dataset is:",round(accuracy,2))
print("Accuracy on training Dataset is:", round(knn.score(X_train,y_train),2))


# Printing Classification Report for Precision, recall and F1 Score
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on test Dataset is: 0.7
# Accuracy on training Dataset is: 0.71
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68       268
#            1       0.93      0.56      0.70       221
#            2       0.64      0.83      0.72       278
#
#     accuracy                           0.70       767
#    macro avg       0.75      0.69      0.70       767
# weighted avg       0.73      0.70      0.70       767

# %% [markdown]
# ### 2.3) Decision Tree Model

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,y, test_size=0.2,random_state = 0)

dt_clf = DecisionTreeClassifier(criterion = 'entropy', random_state= 0) # Defining the classifier used
dt_clf.fit(X_train, y_train)  # Fitting Classifier to the Training Data Set

# Predicting the results below
y_pred = dt_clf.predict(X_test)


# Generating Confusion Matrix
cmatrix = confusion_matrix(y_test, y_pred)

# Generating Accuracy Scores
accuracy = accuracy_score(y_test, y_pred)

#Preparing Confusion Matrix Heatmap
df_for_cm = pd.DataFrame(cmatrix, range(3),range(3))
sns.set(font_scale=1.6)
sns.heatmap(df_for_cm, annot_kws={"size": 15},fmt='g',annot=True)

#Printing results
print("Accuracy on test Dataset is:",round(accuracy,2))
print("Accuracy on training Dataset is:", round(dt_clf.score(X_train,y_train),2))


# Printing Classification Report for Precision, recall and F1 Score
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on test Dataset is: 0.72
# Accuracy on training Dataset is: 1.0
#               precision    recall  f1-score   support
#
#            0       0.69      0.72      0.70       268
#            1       0.79      0.82      0.80       221
#            2       0.70      0.65      0.68       278
#
#     accuracy                           0.72       767
#    macro avg       0.73      0.73      0.73       767
# weighted avg       0.72      0.72      0.72       767

# %% [markdown]
# ### 2.4) Random Forest Model

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,y, test_size=0.2,random_state = 0)
# Defining the classifier used
model = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state=0) 

model.fit(X_train, y_train)     # Fitting Classifier to the Training Data Set

# Predicting the results below
y_pred = model.predict(X_test)

# Generating Confusion Matrix
cmatrix = confusion_matrix(y_test, y_pred)

# Generating Accuracy Scores
accuracy = accuracy_score(y_test, y_pred)

#Preparing Confusion Matrix Heatmap
df_for_cm = pd.DataFrame(cmatrix, range(3),range(3))
sns.set(font_scale=1.6)
sns.heatmap(df_for_cm, annot_kws={"size": 15},fmt='g',annot=True)

#Printing results
print("Accuracy on test Dataset is:",round(accuracy,2))
print("Accuracy on training Dataset is:", round(model.score(X_train,y_train),2))


# Printing Classification Report for Precision, recall and F1 Score
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on test Dataset is: 0.74
# Accuracy on training Dataset is: 0.99
#               precision    recall  f1-score   support
#
#            0       0.67      0.78      0.72       268
#            1       0.82      0.81      0.81       221
#            2       0.77      0.65      0.70       278
#
#     accuracy                           0.74       767
#    macro avg       0.75      0.75      0.75       767
# weighted avg       0.75      0.74      0.74       767

# %% [markdown]
# ### 2.5) SVC Model

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,y, test_size=0.2,random_state = 0)

clf = SVC(kernel = 'linear')    # Defining the classifier used

clf.fit(X_train, y_train)      # Fitting Classifier to the Training Data Set

# Predicting the results below
y_pred = clf.predict(X_test)

# Generating Confusion Matrix
cmatrix = confusion_matrix(y_test, y_pred)

# Generating Accuracy Scores
accuracy = accuracy_score(y_test, y_pred)

#Preparing Confusion Matrix Heatmap
df_for_cm = pd.DataFrame(cmatrix, range(3),range(3))
sns.set(font_scale=1.6)
sns.heatmap(df_for_cm, annot_kws={"size": 15},fmt='g',annot=True)

#Printing results
print("Accuracy on test Dataset is:",round(accuracy,2))
print("Accuracy on training Dataset is:", round(clf.score(X_train,y_train),2))


# Printing Classification Report for Precision, recall and F1 Score
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on test Dataset is: 0.76
# Accuracy on training Dataset is: 0.87
#               precision    recall  f1-score   support
#
#            0       0.70      0.79      0.74       268
#            1       0.86      0.77      0.82       221
#            2       0.76      0.73      0.74       278
#
#     accuracy                           0.76       767
#    macro avg       0.77      0.76      0.77       767
# weighted avg       0.77      0.76      0.76       767

# %% [markdown]
# # J) OUTCOME

# %% [markdown]
# ### **F1 Score Comparison**
# #### **BoW SCORES**
#
# | Model Name | Precision | Recall | F1 | Accuracy |
# | :- | :- | :- | :- | :- |
# |  Naive Bayes  |  0.65    | 0.65  | 0.64  | 0.64  |
# |  KNN  |  0.62    | 0.50  | 0.49  | 0.52  |
# |  Decision Tree |  0.71    | 0.71  | 0.71  | 0.70  |
# |  Random Forest |  0.76    | 0.75   | 0.75   | 0.74   |
# |  SVC |  0.75    | 0.74  | 0.74  | 0.74  |
#
#
#
# #### **TF-IDF SCORES**
#
# | Model Name | Precision | Recall | F1 | Accuracy |
# | :- | :- | :- | :- | :- |
# |  Naive Bayes  |  0.61    | 0.61  | 0.60  | 0.60  |
# |  KNN  |  0.75    | 0.69  | 0.70  | 0.70  |
# |  Decision Tree |  0.73    | 0.73  | 0.73  | 0.72  |
# |  Random Forest |  0.75    | 0.75   | 0.75   | 0.74   |
# |  SVC |  0.77    | 0.76  | 0.77  | 0.76  |
#
# #### **BERT Model**
#
# | Model Name | Precision | Recall | F1 | Accuracy |
# | :- | :- | :- | :- | :- |
# |  BERT  |  0.81    | 0.81  | 0.80  | 0.81  |
