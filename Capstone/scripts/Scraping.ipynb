# %% [markdown]
# # Tweet Scraping
# This file is being used to scrape tweets through 'snscrape' library. We are scraping tweets in batches with hashtags **#immigrant #aapi #racism #chinesevirus #wuhanvirus #commieflu** for the time frame of Jan 2017 to May 2022

# %% [markdown]
# ## Importing Libraries

# %%
import os
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %% [markdown]
# ## Scraping

# %%
# Setting variables to be used below
maxTweets = 100000 #tweet limit

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#aapi since:2017-01-01 until:2022-05-31').get_items()):
    if i>maxTweets:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.location,tweet.retweetCount,tweet.likeCount,tweet.coordinates,tweet.lang,tweet.hashtags])

# %% [markdown]
# ## Converting to DataFrame

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username','Location','Retweet','Like','Place','Lang','Hashtags'])

# Display first 5 entries from dataframe
tweets_df2
# Out:
#                         Datetime             Tweet Id  \
# 0      2022-05-30 23:49:53+00:00  1531422676786352128
# 1      2022-05-30 23:16:28+00:00  1531414268452667398
# 2      2022-05-30 23:05:53+00:00  1531411604910133248
# 3      2022-05-30 23:00:44+00:00  1531410309210152962
# 4      2022-05-30 23:00:17+00:00  1531410194080706565
# ...                          ...                  ...
# 99996  2017-12-31 09:30:00+00:00   947399429383786496
# 99997  2017-12-31 09:00:01+00:00   947391885525516288
# 99998  2017-12-31 08:22:32+00:00   947382453009879040
# 99999  2017-12-31 06:30:00+00:00   947354130661519361
# 100000 2017-12-31 05:30:00+00:00   947339031620259840
#
#                                                      Text       Username  \
# 0       Dance Events at #USAAF2022 #GenerationsOfPower...       APICC_SF
# 1       Streaming AAPI snack stream with @shotaro_VT i...       ToonahVT
# 2       #AAPI month was a great reminder that our stor...  kristykim1015
# ...

# %%
tweets_df2['Text'][323]
# Out:
# 'You are invited to join me in celebrating #AAPIHeritageMonth! Post an image/link that shows a moment, an individual, a book, a movie, food, etc. from an #AAPI culture that brought you joy/a new outlook. No expl. needed. Invite others. For as many days as you want. \n1/2'

# %% [markdown]
# ## Saving to csv

# %%
#tweets_df2.to_csv('data\\aapi_2017_to_may2022.csv',index=False)
